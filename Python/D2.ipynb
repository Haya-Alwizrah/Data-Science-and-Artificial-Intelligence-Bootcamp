# %% [markdown]
# Part one

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# PART THREE (ABOUT SYNATX, VARIABELS, OPERATORS)

# %%
print("HELLO")
# Out:
# HELLO

# %%
print("3 + 5")
# Out:
# 3 + 5

# %% [markdown]
# VARIABLES

# %%
x = 10
name = "ALICE"
price = 99.99
is_valid = True
print(type(x))
print(type(name))
type(price)
type(is_valid)#why did it only return the value of the boolean ?  an overwrite happened  to the vlaues that is why the last vlaue is only printed
# Out:
# <class 'int'>
# <class 'str'>
# bool

# %%
#example one
x = 5
y= "hello, world"

print(x)
print(y)

#example two
x = 4
x = "Amal"
print(x)
# Out:
# 5
# hello, world
# Amal

# %%
a = 4
print(a)
# Out:
# 4

# %%
#Example about Valid names
myvar = "John"
my_var = "John"
_my_var = "John"
myvar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
2var = "A"
# Out:
#   File "/tmp/ipykernel_1435/3535193340.py", line 1
#     2var = "A"
#     ^
# SyntaxError: invalid decimal literal

# %%
-var = "A"
# Out:
#   File "/tmp/ipykernel_1435/483960940.py", line 1
#     -var = "A"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
var-var = "A"
# Out:
#   File "/tmp/ipykernel_1435/4206096394.py", line 1
#     var-var = "A"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#Multiple variables with the same value
x = y = z = "Orange"
print (x)
print (y)
print (z)
# Out:
# Orange
# Orange
# Orange

# %%
x, y = "Orange", ("Banana" , "Cherry")
print(x)
print(y)
print(type(y))
# Out:
# Orange
# ('Banana', 'Cherry')
# <class 'tuple'>

# %%
#printing to the list of keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = "5"
y =3
print(x * y)
# Out:
# 555

# %%
x = "Python is "
y = " Powerful!"
print(x + y)
# Out:
# Python is  Powerful!

# %%
str1 = "What means it has even more than "
str2 = 76
str3 = "quirks"
print(str1, str2, str3)
# Out:
# What means it has even more than  76 quirks

# %%
str1 = "What means it has even more than "
str2 = "76"
str3 = "quirks"
print(str1+ str2+ str3)
# Out:
# What means it has even more than 76quirks

# %% [markdown]
# Way of formatting the output

# %%
name = "python"
version = 3
print("the language is {} and have the version is {}.".format(name,version))
# Out:
# the language is python and have the version is 3.

# %%
name, age = "Ali", 22
print("my name is  {} and I am {} years old". format(name, age))
print(f"my name is  {name} and I am {age} years old")
# Out:
# my name is  Ali and I am 22 years old
# my name is  Ali and I am 22 years old

# %% [markdown]
# Formatting to the decimal number

# %%
pi = 3.14259

# %%
print("Pi rounded to 1 decimal place:{:.1f}".format(pi))
# Out:
# Pi rounded to 1 decimal place:3.1

# %%
print(f"Pi rounded to 1 decimal place: {pi:.1f}")
# Out:
# Pi rounded to 1 decimal place: 3.1

# %% [markdown]
# Practice

# %%
print("Hello","World")
# Out:
# Hello World

# %%
print("my name is", "ali")
print("my name is" + " Ali")
print(f"my name is {'Ali'}")
# Out:
# my name is ali
# my name is Ali
# my name is Ali

# %%
name = "sara"
age = 20
print("my name is", name, "and I am", age, "years old")
# Out:
# my name is sara and I am 20 years old

# %% [markdown]
# Documentation

# %%
"""
this is a long comment
"""

# %%
# this is a short comment

# %%
#python can be used as a calculator
23 *8
# Out:
# 184

# %% [markdown]
# Data Type

# %% [markdown]
# String

# %%
t = "hello world"
t2 = "python is fun"
t3 ="2345"

# %% [markdown]
# Boolean

# %%
right = True
print(type(right))
wrong = False
print(type(wrong))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# Numeric data type

# %%
a = 7
print(type(a))

b = 1.4
print(type(b))

c = 4 + 9j
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# Collection of data

# %% [markdown]
# Casting -> converting from one type to the other

# %% [markdown]
# str -> int

# %%
x = 10
y = "20"
result = x + int(y) #casting here is temproiry
print(result)
# Out:
# 30

# %%
print(type(x))
print(type(y))
y = int(y) #permentant change
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %%
x = 25
y = str(x)
print(type(y))
# Out:
# <class 'str'>

# %% [markdown]
# input -> to take from the user , to make code more flexable

# %%
name = input("What is your name ?")
print("hello", name)
# Out:
# What is your name ?d
# hello d

# %%
age = int(input("how old are you?"))
print("you are", age, "years old")
# Out:
# how old are you?23
# you are 23 years old

# %% [markdown]
# String operation

# %% [markdown]
# Slicing

# %%
x = "Hamad"
print(x[1:2]) #start: end
print(x[:2]) #start : end
print(x[-2:]) #print ad
# Out:
# a
# Ha
# ad

# %% [markdown]
# Membership in the string

# %%
print("s"  in "string")
print("s" not in "xy")
# Out:
# True
# True

# %% [markdown]
# new line in the string

# %%
s = "hello my name is Dalia. \nI love reading books <3"
print(s)
# Out:
# hello my name is Dalia.
# I love reading books <3

# %% [markdown]
# upper(), lower() methods

# %%
x = "into to ai"
x = x.upper()
print(x)


y= "INTRO TO AI"
y = y.lower()
print(y)

x + y
# Out:
# INTO TO AI
# intro to ai
# 'INTO TO AIintro to ai'

# %%
text = "hello world"
print(text.upper())
print(text.capitalize())
print(text.split())
# Out:
# HELLO WORLD
# Hello world
# ['hello', 'world']

# %%
x = "python is fun"
print(x.find("pyt")) #find the substring of the first
print(x.strip().title())
# Out:
# 0
# Python Is Fun

# %%
word = "python123"
print(word.isalpha()) #is all the string alphabet?
# Out:
# False

# %%
#startswith
#endswith methods
#isdigit
#islower
#isupper

# %% [markdown]
# OPERATORS
