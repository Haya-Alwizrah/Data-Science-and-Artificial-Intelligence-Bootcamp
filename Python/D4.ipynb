# %% [markdown]
# # if statement

# %%
age = 20
print ("adult") if age >= 18 else print("minor")
# Out:
# adult

# %%
age = 8
print ("adult") if age >= 18 else print("minor")
# Out:
# minor

# %%
x = int(input())

print("pass") if x >= 60 else print("fail")
# Out:
# fail
